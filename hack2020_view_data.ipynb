# %%
import pandas as pd

# %%
df1 = pd.read_csv('csv/Cat.csv', nrows=5)

# %%
df2 = pd.read_csv('csv/E_1.csv', nrows=5)

# %%
df3 = pd.read_csv('csv/E_2.csv', nrows=5)

# %%
df4 = pd.read_csv('csv/readers.csv', nrows=5)

# %%
df5 = pd.read_csv('csv/V_1.csv', nrows=5)

# %%
df6 = pd.read_csv('csv/V_2.csv', nrows=5)

# %%
df7 = pd.read_csv('Classificator_hachaton.csv', nrows=5)

# %%
df8 = pd.read_csv('MegaRelation_hackaton.csv', nrows=5)

# %%
df9 = pd.read_csv('org_hackaton.csv', nrows=5)

# %%
df10 = pd.read_csv('Pupil_hackaton.csv', nrows=5)

# %%
df11 = pd.read_csv('request_hackaton.csv', nrows=5)

# %%
df12 = pd.read_csv('services_hackaton.csv', nrows=5)

# %%
df13 = pd.read_excel('Мероприятия.xlsx')

# %% [markdown]
# ## Книги

# %%
df1 # Каталог
# Out:
#    Unnamed: 0  doc_id                        p100a          p245a   p260a  \
# 0           0       1  Устинова Татьяна Витальевна  Призрак Канта  Москва
# 1           1       2                          NaN  Наука и жизнь  Москва
# 2           2       3                          NaN  Наука и жизнь     NaN
# 3           3       4                          NaN  Наука и жизнь     NaN
# 4           4       5                          NaN  Наука и жизнь     NaN
#
#                                   p260b  p260c  \
# 0                                 Эксмо   2018
# 1  АНО Редакция журнала «Наука и жизнь»  1938-
# 2                                   NaN   2018
# 3                                   NaN   2018
# 4                                   NaN   2018
#
#                                    p490a  \
# 0  Татьяна Устинова. Первая среди лучших
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# ...

# %%
df2 # Экземпляры1
# Out:
#    Unnamed: 0  Идентификатор экземпляра  ИД Каталожной записи  \
# 0           0                  12488544                     1
# 1           1                  12488546                     1
# 2           2                  12488542                     1
# 3           3                  13671389                     1
# 4           4                   7625486                     1
#
#   Инвентарный номер     Штрих-код  Раздел знаний  Идентификатор сиглы
# 0     09:0000120386  980007854120  84(2Рос=Рус)6                314.0
# 1     09:0000152427  980010247056  84(2Рос=Рус)6                320.0
# 2     09:0000240622  980000737154  84(2Рос=Рус)6                306.0
# 3     09:0000278133  980005475303  84(2Рос=Рус)6                308.0
# 4     05:0000257728  580001931461  84(2Рос=Рус)6                293.0

# %%
df3 # Экземпляры2
# Out:
#    Unnamed: 0  Идентификатор экземпляра  ИД Каталожной записи  \
# 0           0                   2830404                399001
# 1           1                   2830403                399001
# 2           2                   2781735                399001
# 3           3                   2781737                399001
# 4           4                   2781738                399001
#
#   Инвентарный номер     Штрих-код Раздел знаний  Идентификатор сиглы
# 0     01:0000019698  181000142300      84(4Шва)                112.0
# 1     01:0000027988  181000441335    84(4Швейц)                113.0
# 2     02:0000583817  280005456044      84(4Шва)                 81.0
# 3     02:0000855574  280011962379    84(4Швейц)                 87.0
# 4     02:0000462824  280008297767      84(4Шва)                 87.0

# %%
df4 # Читатели
# Out:
#    Unnamed: 0  ID читателя        Дата рождения
# 0           0       366670  1974-10-14 00:00:00
# 1           1       235264  1978-06-01 00:00:00
# 2           2       133225  1976-01-06 00:00:00
# 3           3       556716  1989-01-28 00:00:00
# 4           4        52086  1955-08-14 00:00:00

# %%
df5 # Выдача1
# Out:
#    Unnamed: 0  ИД выдачи  ИД читателя Инвентарный номер     Штрих-код  \
# 0           0          1          179     03:0000005767  381000177719
# 1           1          2          179     03:0000005761  381000196420
# 2           2          3          179     03:0000005767  381000177719
# 3           3          4          179     03:0000005767  381000177719
# 4           4          5          179     03:0000005767  381000177719
#
#            Дата выдачи Дата сдачи (предполагаемая)  Состояние  Unnamed: 7  \
# 0  2018-04-13 15:00:00         2018-04-13 15:00:00       6545         NaN
# 1  2018-04-13 15:00:00         2018-04-16 15:00:00       6548         NaN
# 2  2018-04-13 15:00:00         2018-04-13 15:00:00       6545         NaN
# 3  2018-04-13 15:00:00         2018-04-13 15:00:00       6545         NaN
# 4  2018-04-13 15:00:00         2018-04-13 15:00:00       6548         NaN
#
#    Состояния        Unnamed: 9
# 0     6544.0          На руках
# 1     6545.0      Переоформлен
# ...

# %%
df6 # Выдача2
# Out:
#    Unnamed: 0  ИД выдачи  ИД читателя Инвентарный номер     Штрих-код  \
# 0           0    6000001       159558     05:0000075032  580000904657
# 1           1    6000002       159558     05:0000074245  580000904060
# 2           2    6000003       159558     05:0000075206  580000904855
# 3           3    6000004       348361     07:0000464307  780003931081
# 4           4    6000005       344222     09:0000241136  980006806892
#
#            Дата выдачи Дата сдачи (предполагаемая)  Состояние  Unnamed: 7  \
# 0  2020-01-24 15:00:00         2020-02-05 15:00:00       6548         NaN
# 1  2020-01-24 15:00:00         2020-02-05 15:00:00       6545         NaN
# 2  2020-01-24 15:00:00         2020-02-05 15:00:00       6545         NaN
# 3  2020-01-24 15:00:00         2020-01-29 15:00:00       6548         NaN
# 4  2020-01-24 15:00:00         2020-01-24 15:00:00       6548         NaN
#
#    Состояния        Unnamed: 9
# 0     6544.0          На руках
# 1     6545.0      Переоформлен
# ...

# %% [markdown]
# ## Кружки

# %%
df7 #Классификатор кружков
# Out:
#   id_классификатора;"id_родительского_классификатора";"Наименование"
# 0                           3002985;null;"Автошкола"
# 1                         3002986;3002985;"Автоклуб"
# 2       3002987;3002985;"Правила дорожного движения"
# 3                    3002988;3002985;"Юный водитель"
# 4                         3002989;null;"Архитектура"

# %%
df8 # Таблица связи
# Out:
#   id_зачисления;"Статус";"id_ученика";"Дата_создания_записи";"id_организации";"id_заявления";"id_услуги";"дата_зачисления";"дата_отчисления";"причина_перевода";"предыдущая_запись_зачисления";"следующая_запись_зачисления";"Плановая_дата_начала_занятий";"Плановая_дата_окончания_занятий"
# 0  1325954;3;25969;08.06.2015 14:47:19;30;950832;...
# 1  2879918;3;158129;29.10.2015 18:35:21;30;989658...
# 2  2901258;3;304476;02.11.2015 14:05:56;30;950764...
# 3  2912724;3;1139915;03.11.2015 14:29:27;30;95078...
# 4  2912819;3;298767;03.11.2015 14:34:15;30;950799...

# %%
df9 # Организации
# Out:
#   id_организации;"полное_наименование";"краткое_наименование";"улица";"Метро"
# 0  1;"Государственное бюджетное образовательное у...
# 1  2;"Государственное бюджетное профессиональное ...
# 2  2;"Государственное бюджетное профессиональное ...
# 3  3;"Государственное бюджетное образовательном у...
# 4  4;"Государственное бюджетное образовательное у...

# %%
df10 # Ученики
# Out:
#   id_ученика;"возраст";"пол"
# 0             1;12;"Женский"
# 1             2;12;"Женский"
# 2             3;12;"Женский"
# 3             4;11;"Женский"
# 4             5;12;"Женский"

# %%
df11
# Out:
#   id_заявления;"статус_заявления";"дата_создания";"оценка_вступительных_испытаний";"Испытания_пройдены";"Зачисление_разрешено";"Зачисление_не_разрешено";"Причина_отказа_в_зачислении";"id_услуги"
# 0  989578;"Ожидание прихода Заявителя на вступите...
# 1  3571456;"Архив";05.11.2015 18:51:59;5;1;0;null...
# 2  3571725;"Отказ в зачислении";05.11.2015 19:35:...
# 3  950963;"Ожидание прихода Заявителя на вступите...
# 4  952962;"Ожидание прихода Заявителя на вступите...

# %%
df12
# Out:
#                                                    id_услуги;"Тип_финансирования";"Классификатор_услуги";"id_организации";"Тип_расписания";"Наименование_услуги";"Дата_создания";"длительность_обучения";"единица_длительности"
# 39178;"бесплатно";3000001;30;"Индивидуальное";"...                                        0000";"лет"
# 39181;"бесплатно";3000001;30;"Индивидуальное";"...                                        0000";"лет"
# 212072;"бесплатно";3000001;30;"Индивидуальное";...                                        0000";"лет"
# 212517;"бесплатно";3000001;30;"Индивидуальное";...                                        0000";"лет"
# 39913;"бесплатно";3000003;45;"Индивидуальное";"...                                        0000";"лет"

# %% [markdown]
# ## Мероприятия

# %%
df13.head()
# Out:
#      id                               Название мероприятия     Статус  \
# 0     5  Фестивлаь современных молодежных уличных культ...  Завершено
# 1    12  Танцевальный вечер "Ретро" в честь Дня Победы ...  Завершено
# 2  3179                                           Врасплох  Завершено
# 3   486  Праздник Новогодней елки. Новогодний концерт в...  Завершено
# 4  2100                Выставка к Рождеству "Сувенир Года"  Завершено
#
#                  Наименование учреждения Тип учреждения Подразделение  \
# 0     ГБУК г. Москвы «Клуб «Современник»  Дома культуры           NaN
# 1           ГБУК г.Москвы «ДК «Нагорный»  Дома культуры           NaN
# 2          ГБУК г. Москвы «ДК «Нагатино»  Дома культуры           NaN
# 3  ГАУК г. Москвы «Культурный центр ЗИЛ»  Дома культуры           NaN
# 4            ГБУК г.Москвы ТКС «Орехово»  Дома культуры           NaN
#
#   Стоимость (полная)                     Тип мероприятия  \
# 0         бесплатное                           фестиваль
# ...
